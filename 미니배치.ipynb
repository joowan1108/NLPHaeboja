# %% [markdown]
# #미니 배치

# %% [markdown]
# 배치 크기는 보통 2의 제곱수를 사용합니다. ex) 2, 4, 8, 16, 32, 64... 그 이유는 CPU와 GPU의 메모리가 2의 배수이므로 배치크기가 2의 제곱수일 경우에 데이터 송수신의 효율을 높일 수 있다고 합니다.

# %% [markdown]
# 미니배치는 k개 데이터에 대해 훈련을 한 후, parameter를 update하는 것이다. iteration은 k개 데이터를 쓴 뒤에 1이 차감된다.

# %% [markdown]
# #미니 배치 학습을 도와주는 파이토치 도구

# %% [markdown]
# #데이터 로드하기

# %% [markdown]
# 파이토치는 데이터를 쉽게 다룰 수 있도록 데이터셋과 데이터로더를 제공한다. 이를 통해 데이터 셔플, 병렬 처리 등을 할 수 있다.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더

# %%
x_train  =  torch.FloatTensor([[73,  80,  75],
                               [93,  88,  93],
                               [89,  91,  90],
                               [96,  98,  100],
                               [73,  66,  70]])
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %% [markdown]
# Dataset을 만들어야지 데이터로더를 사용할 수 있다. 데이터 로더는 2개의 인자를 필수로 입력받는다. 첫 번째로 dataset, 두 번째로 mini batch의 크기를 입력받는다. 추가로, shuffle 인자를 통해 데이터셋을 섞어서 학습할 것인지를 정할 수 있다.

# %% [markdown]
# 학습할 때마다 dataset의 순서를 동일하게 한다면 overfitting이 발생할 수 있다.

# %%
dataLoader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
#모델과 optimizer 정의
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataLoader):
    print("batch_idx: ", batch_idx)
    print("samples: ", samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataLoader),
        cost.item()
        ))
# Out:
# batch_idx:  0
# samples:  [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    0/20 Batch 1/3 Cost: 21118.486328
# batch_idx:  1
# samples:  [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    0/20 Batch 2/3 Cost: 7379.447266
# batch_idx:  2
# samples:  [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    0/20 Batch 3/3 Cost: 3647.044189
# batch_idx:  0
# samples:  [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    1/20 Batch 1/3 Cost: 613.396484
# batch_idx:  1
# samples:  [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    1/20 Batch 2/3 Cost: 100.293884
# batch_idx:  2
# samples:  [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    1/20 Batch 3/3 Cost: 67.777542
# batch_idx:  0
# samples:  [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    2/20 Batch 1/3 Cost: 14.930281
# batch_idx:  1
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch    2/20 Batch 2/3 Cost: 14.140786
# batch_idx:  2
# samples:  [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    2/20 Batch 3/3 Cost: 0.372064
# batch_idx:  0
# samples:  [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    3/20 Batch 1/3 Cost: 11.022314
# batch_idx:  1
# samples:  [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch    3/20 Batch 2/3 Cost: 2.071188
# batch_idx:  2
# samples:  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    3/20 Batch 3/3 Cost: 3.431731
# batch_idx:  0
# samples:  [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    4/20 Batch 1/3 Cost: 5.750562
# batch_idx:  1
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch    4/20 Batch 2/3 Cost: 1.747153
# batch_idx:  2
# samples:  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    4/20 Batch 3/3 Cost: 9.229039
# batch_idx:  0
# samples:  [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    5/20 Batch 1/3 Cost: 3.851347
# batch_idx:  1
# samples:  [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    5/20 Batch 2/3 Cost: 4.764602
# batch_idx:  2
# samples:  [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    5/20 Batch 3/3 Cost: 0.942176
# batch_idx:  0
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch    6/20 Batch 1/3 Cost: 0.799418
# batch_idx:  1
# samples:  [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    6/20 Batch 2/3 Cost: 5.496515
# batch_idx:  2
# samples:  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    6/20 Batch 3/3 Cost: 7.051855
# batch_idx:  0
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch    7/20 Batch 1/3 Cost: 2.794408
# batch_idx:  1
# samples:  [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    7/20 Batch 2/3 Cost: 3.464592
# batch_idx:  2
# samples:  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    7/20 Batch 3/3 Cost: 7.072129
# batch_idx:  0
# samples:  [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch    8/20 Batch 1/3 Cost: 0.442189
# batch_idx:  1
# samples:  [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch    8/20 Batch 2/3 Cost: 5.622170
# batch_idx:  2
# samples:  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    8/20 Batch 3/3 Cost: 7.020204
# batch_idx:  0
# samples:  [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    9/20 Batch 1/3 Cost: 3.387331
# batch_idx:  1
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch    9/20 Batch 2/3 Cost: 4.183258
# batch_idx:  2
# samples:  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    9/20 Batch 3/3 Cost: 6.997500
# batch_idx:  0
# samples:  [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   10/20 Batch 1/3 Cost: 3.162410
# batch_idx:  1
# samples:  [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   10/20 Batch 2/3 Cost: 4.905116
# batch_idx:  2
# samples:  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   10/20 Batch 3/3 Cost: 5.763413
# batch_idx:  0
# samples:  [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   11/20 Batch 1/3 Cost: 2.311885
# batch_idx:  1
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   11/20 Batch 2/3 Cost: 7.099895
# batch_idx:  2
# samples:  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   11/20 Batch 3/3 Cost: 5.350903
# batch_idx:  0
# samples:  [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   12/20 Batch 1/3 Cost: 4.633292
# batch_idx:  1
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   12/20 Batch 2/3 Cost: 3.362898
# batch_idx:  2
# samples:  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   12/20 Batch 3/3 Cost: 5.375215
# batch_idx:  0
# samples:  [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   13/20 Batch 1/3 Cost: 4.644811
# batch_idx:  1
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   13/20 Batch 2/3 Cost: 3.287350
# batch_idx:  2
# samples:  [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   13/20 Batch 3/3 Cost: 5.232475
# batch_idx:  0
# samples:  [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   14/20 Batch 1/3 Cost: 8.896678
# batch_idx:  1
# samples:  [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   14/20 Batch 2/3 Cost: 5.257555
# batch_idx:  2
# samples:  [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   14/20 Batch 3/3 Cost: 0.020784
# batch_idx:  0
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   15/20 Batch 1/3 Cost: 0.382076
# batch_idx:  1
# samples:  [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   15/20 Batch 2/3 Cost: 5.544024
# batch_idx:  2
# samples:  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   15/20 Batch 3/3 Cost: 7.509303
# batch_idx:  0
# samples:  [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   16/20 Batch 1/3 Cost: 5.246687
# batch_idx:  1
# samples:  [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   16/20 Batch 2/3 Cost: 3.616331
# batch_idx:  2
# samples:  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   16/20 Batch 3/3 Cost: 5.231707
# batch_idx:  0
# samples:  [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   17/20 Batch 1/3 Cost: 5.855688
# batch_idx:  1
# samples:  [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   17/20 Batch 2/3 Cost: 3.525893
# batch_idx:  2
# samples:  [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   17/20 Batch 3/3 Cost: 5.080437
# batch_idx:  0
# samples:  [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   18/20 Batch 1/3 Cost: 4.211923
# batch_idx:  1
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   18/20 Batch 2/3 Cost: 4.767910
# batch_idx:  2
# samples:  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   18/20 Batch 3/3 Cost: 5.932558
# batch_idx:  0
# samples:  [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   19/20 Batch 1/3 Cost: 4.346898
# batch_idx:  1
# samples:  [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   19/20 Batch 2/3 Cost: 5.078587
# batch_idx:  2
# samples:  [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   19/20 Batch 3/3 Cost: 5.007103
# batch_idx:  0
# samples:  [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   20/20 Batch 1/3 Cost: 2.849358
# batch_idx:  1
# samples:  [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   20/20 Batch 2/3 Cost: 4.969117
# batch_idx:  2
# samples:  [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   20/20 Batch 3/3 Cost: 4.128581
